# %% [markdown]
# set j "jobs" /1*3/;
# alias (j,jp);
#
# parameter p(j) "process time of j"
# / 1  15,    2  6,       3  9/;
#
# scalar M "bigM";
# M = sum(j, p(j));
# free variable MeanComp   "Mean completion time";
# positive variables x(j)  "Start time of job j";
# binary variables y(j,jp) "Disjunctive variable for j and jp";
#
# EQUATIONS
# MeanCeqn    "Mean completion time",
# Disj1(j,jp) "Disjunctive part 1",
# Disj2(j,jp) "Disjunctive part 2";
#
# MeanCeqn..   MeanComp =E= sum(j, x(j)+p(j) ) / card(j);
# Disj1(j,jp)$(ord(j) lt ord(jp)).. x(j) + p(j)  =L= x(jp) + M*(1-y(j,jp));
# Disj2(j,jp)$(ord(j) lt ord(jp)).. x(jp)+ p(jp) =L= x(j)  + M*y(j,jp);
#
# MODEL simplesched /all/;
# SOLVE simplesched using MIP minimizing MeanComp;
#
# https://learnche.org/4G3/Mixed-Integer_linear_programming
# https://docs.google.com/document/d/1lmBL1Bh251VYb7NmBD2ER-JPD2DSExGR87nu7AWs7oo/edit
# https://docs.google.com/document/d/1VZRQ_aaQjMiK_brME9y1dhHYtkhTI_2NLt4PQ51OyhM/edit

# %%
from pyomo.environ import *
model = ConcreteModel()

# %%
model.j = RangeSet( 3 )
model.jp= RangeSet( 3 )
p={1:15,2:6,3:9}
M=sum(p.values())+10
model.p=Param(model.j,initialize=p)
model.x=Var(model.j,within=NonNegativeReals)
model.y=Var(model.j,model.jp,within=Binary)
model.x.pprint()
model.p.pprint()
# Out:
# x : Size=3, Index=j
#     Key : Lower : Value : Upper : Fixed : Stale : Domain
#       1 :     0 :  None :  None : False :  True : NonNegativeReals
#       2 :     0 :  None :  None : False :  True : NonNegativeReals
#       3 :     0 :  None :  None : False :  True : NonNegativeReals
# p : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#     Key : Value
#       1 :    15
#       2 :     6
#       3 :     9

# %%
model.Obj = Objective(expr=(sum(model.x[j]+model.p[j] for j in model.j)/max(model.j)) , sense=minimize)

# %%
def disj1 (model,j,jp):
    if j<jp:
        return model.x[j] + model.p[j]  <= model.x[jp] + M*(1-model.y[j,jp])
    else:
        return model.x[j] >=0
def disj2 (model,j,jp):
    if j<jp:
        return model.x[jp] + model.p[jp]  <= model.x[j] + M*model.y[j,jp]
    else:
        return model.x[j] >=0
        
model.c1= Constraint( model.j,model.jp, rule=disj1 )
model.c2= Constraint( model.j,model.jp, rule=disj2 )
results = SolverFactory('glpk').solve(model).write()
model.pprint()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 17.0
#   Upper bound: 17.0
#   Number of objectives: 1
#   Number of constraints: 19
#   Number of variables: 7
#   Number of nonzeros: 31
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 9
#       Number of created subproblems: 9
#   Error rc: 0
#   Time: 0.027807950973510742
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# 3 Set Declarations
#     c1_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#     c2_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#     y_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#
# 2 RangeSet Declarations
#     j : Dimen=1, Size=3, Bounds=(1, 3)
#         Key  : Finite : Members
#         None :   True :   [1:3]
#     jp : Dimen=1, Size=3, Bounds=(1, 3)
#         Key  : Finite : Members
#         None :   True :   [1:3]
#
# 1 Param Declarations
#     p : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    15
#           2 :     6
#           3 :     9
#
# 2 Var Declarations
#     x : Size=3, Index=j
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :  15.0 :  None : False : False : NonNegativeReals
#           2 :     0 :   0.0 :  None : False : False : NonNegativeReals
#           3 :     0 :   6.0 :  None : False : False : NonNegativeReals
#     y : Size=9, Index=y_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :     0 :  None :     1 : False :  True : Binary
#         (1, 2) :     0 :   0.0 :     1 : False : False : Binary
#         (1, 3) :     0 :   0.0 :     1 : False : False : Binary
#         (2, 1) :     0 :  None :     1 : False :  True : Binary
#         (2, 2) :     0 :  None :     1 : False :  True : Binary
#         (2, 3) :     0 :   1.0 :     1 : False : False : Binary
#         (3, 1) :     0 :  None :     1 : False :  True : Binary
#         (3, 2) :     0 :  None :     1 : False :  True : Binary
#         (3, 3) :     0 :  None :     1 : False :  True : Binary
#
# 1 Objective Declarations
#     Obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : (x[1] + 15 + x[2] + 6 + x[3] + 9)/3
#
# 2 Constraint Declarations
#     c1 : Size=9, Index=c1_index, Active=True
#         Key    : Lower : Body                                 : Upper : Active
#         (1, 1) :   0.0 :                                 x[1] :  +Inf :   True
#         (1, 2) :  -Inf : x[1] + 15 - (x[2] + 40*(1 - y[1,2])) :   0.0 :   True
#         (1, 3) :  -Inf : x[1] + 15 - (x[3] + 40*(1 - y[1,3])) :   0.0 :   True
#         (2, 1) :   0.0 :                                 x[2] :  +Inf :   True
#         (2, 2) :   0.0 :                                 x[2] :  +Inf :   True
#         (2, 3) :  -Inf :  x[2] + 6 - (x[3] + 40*(1 - y[2,3])) :   0.0 :   True
#         (3, 1) :   0.0 :                                 x[3] :  +Inf :   True
#         (3, 2) :   0.0 :                                 x[3] :  +Inf :   True
#         (3, 3) :   0.0 :                                 x[3] :  +Inf :   True
#     c2 : Size=9, Index=c2_index, Active=True
#         Key    : Lower : Body                          : Upper : Active
#         (1, 1) :   0.0 :                          x[1] :  +Inf :   True
#         (1, 2) :  -Inf : x[2] + 6 - (x[1] + 40*y[1,2]) :   0.0 :   True
#         (1, 3) :  -Inf : x[3] + 9 - (x[1] + 40*y[1,3]) :   0.0 :   True
#         (2, 1) :   0.0 :                          x[2] :  +Inf :   True
#         (2, 2) :   0.0 :                          x[2] :  +Inf :   True
#         (2, 3) :  -Inf : x[3] + 9 - (x[2] + 40*y[2,3]) :   0.0 :   True
#         (3, 1) :   0.0 :                          x[3] :  +Inf :   True
#         (3, 2) :   0.0 :                          x[3] :  +Inf :   True
#         (3, 3) :   0.0 :                          x[3] :  +Inf :   True
#
# 11 Declarations: j jp p x y_index y Obj c1_index c1 c2_index c2

# %%
### Adding a release date
r={1:1,2:1,3:15}
model.r=Param(model.j,initialize=r)
def release(model,j):
    return model.x[j]>=model.r[j]
model.c3=Constraint(model.j,rule=release)
results = SolverFactory('glpk').solve(model).write()
model.pprint()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 20.0
#   Upper bound: 20.0
#   Number of objectives: 1
#   Number of constraints: 22
#   Number of variables: 7
#   Number of nonzeros: 34
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 7
#       Number of created subproblems: 7
#   Error rc: 0
#   Time: 0.027638912200927734
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# 3 Set Declarations
#     c1_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#     c2_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#     y_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#
# 2 RangeSet Declarations
#     j : Dimen=1, Size=3, Bounds=(1, 3)
#         Key  : Finite : Members
#         None :   True :   [1:3]
#     jp : Dimen=1, Size=3, Bounds=(1, 3)
#         Key  : Finite : Members
#         None :   True :   [1:3]
#
# 2 Param Declarations
#     p : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    15
#           2 :     6
#           3 :     9
#     r : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :     1
#           2 :     1
#           3 :    15
#
# 2 Var Declarations
#     x : Size=3, Index=j
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :   7.0 :  None : False : False : NonNegativeReals
#           2 :     0 :   1.0 :  None : False : False : NonNegativeReals
#           3 :     0 :  22.0 :  None : False : False : NonNegativeReals
#     y : Size=9, Index=y_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :     0 :  None :     1 : False :  True : Binary
#         (1, 2) :     0 :   0.0 :     1 : False : False : Binary
#         (1, 3) :     0 :   1.0 :     1 : False : False : Binary
#         (2, 1) :     0 :  None :     1 : False :  True : Binary
#         (2, 2) :     0 :  None :     1 : False :  True : Binary
#         (2, 3) :     0 :   1.0 :     1 : False : False : Binary
#         (3, 1) :     0 :  None :     1 : False :  True : Binary
#         (3, 2) :     0 :  None :     1 : False :  True : Binary
#         (3, 3) :     0 :  None :     1 : False :  True : Binary
#
# 1 Objective Declarations
#     Obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : (x[1] + 15 + x[2] + 6 + x[3] + 9)/3
#
# 3 Constraint Declarations
#     c1 : Size=9, Index=c1_index, Active=True
#         Key    : Lower : Body                                 : Upper : Active
#         (1, 1) :   0.0 :                                 x[1] :  +Inf :   True
#         (1, 2) :  -Inf : x[1] + 15 - (x[2] + 40*(1 - y[1,2])) :   0.0 :   True
#         (1, 3) :  -Inf : x[1] + 15 - (x[3] + 40*(1 - y[1,3])) :   0.0 :   True
#         (2, 1) :   0.0 :                                 x[2] :  +Inf :   True
#         (2, 2) :   0.0 :                                 x[2] :  +Inf :   True
#         (2, 3) :  -Inf :  x[2] + 6 - (x[3] + 40*(1 - y[2,3])) :   0.0 :   True
#         (3, 1) :   0.0 :                                 x[3] :  +Inf :   True
#         (3, 2) :   0.0 :                                 x[3] :  +Inf :   True
#         (3, 3) :   0.0 :                                 x[3] :  +Inf :   True
#     c2 : Size=9, Index=c2_index, Active=True
#         Key    : Lower : Body                          : Upper : Active
#         (1, 1) :   0.0 :                          x[1] :  +Inf :   True
#         (1, 2) :  -Inf : x[2] + 6 - (x[1] + 40*y[1,2]) :   0.0 :   True
#         (1, 3) :  -Inf : x[3] + 9 - (x[1] + 40*y[1,3]) :   0.0 :   True
#         (2, 1) :   0.0 :                          x[2] :  +Inf :   True
#         (2, 2) :   0.0 :                          x[2] :  +Inf :   True
#         (2, 3) :  -Inf : x[3] + 9 - (x[2] + 40*y[2,3]) :   0.0 :   True
#         (3, 1) :   0.0 :                          x[3] :  +Inf :   True
#         (3, 2) :   0.0 :                          x[3] :  +Inf :   True
#         (3, 3) :   0.0 :                          x[3] :  +Inf :   True
#     c3 : Size=3, Index=j, Active=True
#         Key : Lower : Body : Upper : Active
#           1 :   1.0 : x[1] :  +Inf :   True
#           2 :   1.0 : x[2] :  +Inf :   True
#           3 :  15.0 : x[3] :  +Inf :   True
#
# 13 Declarations: j jp p x y_index y Obj c1_index c1 c2_index c2 r c3

# %%
### Adding a due date for jobs
d={1:20,2:50,3:50}
model.d=Param(model.j,initialize=d)
def due(model,j):
    return model.x[j]+model.p[j] <=model.d[j]
model.c4=Constraint(model.j,rule=due)
results = SolverFactory('glpk').solve(model).write()
model.pprint()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 23.0
#   Upper bound: 23.0
#   Number of objectives: 1
#   Number of constraints: 25
#   Number of variables: 7
#   Number of nonzeros: 37
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 3
#       Number of created subproblems: 3
#   Error rc: 0
#   Time: 0.03779435157775879
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# 3 Set Declarations
#     c1_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#     c2_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#     y_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain : Size : Members
#         None :     2 :   j*jp :    9 : {(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)}
#
# 2 RangeSet Declarations
#     j : Dimen=1, Size=3, Bounds=(1, 3)
#         Key  : Finite : Members
#         None :   True :   [1:3]
#     jp : Dimen=1, Size=3, Bounds=(1, 3)
#         Key  : Finite : Members
#         None :   True :   [1:3]
#
# 3 Param Declarations
#     d : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    20
#           2 :    50
#           3 :    50
#     p : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :    15
#           2 :     6
#           3 :     9
#     r : Size=3, Index=j, Domain=Any, Default=None, Mutable=False
#         Key : Value
#           1 :     1
#           2 :     1
#           3 :    15
#
# 2 Var Declarations
#     x : Size=3, Index=j
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           1 :     0 :   1.0 :  None : False : False : NonNegativeReals
#           2 :     0 :  16.0 :  None : False : False : NonNegativeReals
#           3 :     0 :  22.0 :  None : False : False : NonNegativeReals
#     y : Size=9, Index=y_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :     0 :  None :     1 : False :  True : Binary
#         (1, 2) :     0 :   1.0 :     1 : False : False : Binary
#         (1, 3) :     0 :   1.0 :     1 : False : False : Binary
#         (2, 1) :     0 :  None :     1 : False :  True : Binary
#         (2, 2) :     0 :  None :     1 : False :  True : Binary
#         (2, 3) :     0 :   1.0 :     1 : False : False : Binary
#         (3, 1) :     0 :  None :     1 : False :  True : Binary
#         (3, 2) :     0 :  None :     1 : False :  True : Binary
#         (3, 3) :     0 :  None :     1 : False :  True : Binary
#
# 1 Objective Declarations
#     Obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : (x[1] + 15 + x[2] + 6 + x[3] + 9)/3
#
# 4 Constraint Declarations
#     c1 : Size=9, Index=c1_index, Active=True
#         Key    : Lower : Body                                 : Upper : Active
#         (1, 1) :   0.0 :                                 x[1] :  +Inf :   True
#         (1, 2) :  -Inf : x[1] + 15 - (x[2] + 40*(1 - y[1,2])) :   0.0 :   True
#         (1, 3) :  -Inf : x[1] + 15 - (x[3] + 40*(1 - y[1,3])) :   0.0 :   True
#         (2, 1) :   0.0 :                                 x[2] :  +Inf :   True
#         (2, 2) :   0.0 :                                 x[2] :  +Inf :   True
#         (2, 3) :  -Inf :  x[2] + 6 - (x[3] + 40*(1 - y[2,3])) :   0.0 :   True
#         (3, 1) :   0.0 :                                 x[3] :  +Inf :   True
#         (3, 2) :   0.0 :                                 x[3] :  +Inf :   True
#         (3, 3) :   0.0 :                                 x[3] :  +Inf :   True
#     c2 : Size=9, Index=c2_index, Active=True
#         Key    : Lower : Body                          : Upper : Active
#         (1, 1) :   0.0 :                          x[1] :  +Inf :   True
#         (1, 2) :  -Inf : x[2] + 6 - (x[1] + 40*y[1,2]) :   0.0 :   True
#         (1, 3) :  -Inf : x[3] + 9 - (x[1] + 40*y[1,3]) :   0.0 :   True
#         (2, 1) :   0.0 :                          x[2] :  +Inf :   True
#         (2, 2) :   0.0 :                          x[2] :  +Inf :   True
#         (2, 3) :  -Inf : x[3] + 9 - (x[2] + 40*y[2,3]) :   0.0 :   True
#         (3, 1) :   0.0 :                          x[3] :  +Inf :   True
#         (3, 2) :   0.0 :                          x[3] :  +Inf :   True
#         (3, 3) :   0.0 :                          x[3] :  +Inf :   True
#     c3 : Size=3, Index=j, Active=True
#         Key : Lower : Body : Upper : Active
#           1 :   1.0 : x[1] :  +Inf :   True
#           2 :   1.0 : x[2] :  +Inf :   True
#           3 :  15.0 : x[3] :  +Inf :   True
#     c4 : Size=3, Index=j, Active=True
#         Key : Lower : Body      : Upper : Active
#           1 :  -Inf : x[1] + 15 :  20.0 :   True
#           2 :  -Inf :  x[2] + 6 :  50.0 :   True
#           3 :  -Inf :  x[3] + 9 :  50.0 :   True
#
# 15 Declarations: j jp p x y_index y Obj c1_index c1 c2_index c2 r c3 d c4
